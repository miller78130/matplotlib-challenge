# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1) It appears the experiment was setup dividing the number of mice as equally as possible betweeen the different drugs used.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files

mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results

mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset

mouse_study = pd.merge(mouse_metadata, study_results, how="outer", on="Mouse ID")
# Display the data table for preview

mouse_study.head(15)
#mouse_metadata.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %%
# Checking the number of mice.
mice_number = len(mouse_metadata["Mouse ID"])
mice_number
# Out:
# 249

# %%
mice_number2 = len(study_results["Mouse ID"])
mice_number2
# Out:
# 1893

# %%
mice_number3 = len(mouse_study["Mouse ID"])
mice_number3
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

mouse_study.duplicated(subset=["Mouse ID", "Timepoint"]).sum()
# Out:
# 5

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

mouse_study_clean = mouse_study.drop_duplicates(subset=['Mouse ID', 'Timepoint'], keep = 'last')

# Checking the number of mice in the clean DataFrame.

print(len(mouse_study_clean))
# Out:
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
reg_stats = mouse_study_clean.groupby(['Drug Regimen']).describe()
tumor_stats = reg_stats.loc[:,'Tumor Volume (mm3)']

tumor_stats
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      156.0  52.382993  6.574208  45.000000  47.046068  50.783528
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        max
# Drug Regimen
# Capomulin     45.000000  48.158209
# Ceftamin      56.801438  68.923185
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.

reg_mean = mouse_study_clean.groupby(["Drug Regimen"]).mean()
tumor_mean =reg_mean.loc[:,'Tumor Volume (mm3)']

reg_median = mouse_study_clean.groupby(["Drug Regimen"]).median()
tumor_median = reg_median.loc[:,'Tumor Volume (mm3)']

reg_var = mouse_study_clean.groupby(['Drug Regimen']).var()
tumor_var = reg_var.loc[:,'Tumor Volume (mm3)']

reg_std = mouse_study_clean.groupby(['Drug Regimen']).std()
tumor_std = reg_std.loc[:,'Tumor Volume (mm3)']

reg_sem = mouse_study_clean.groupby(['Drug Regimen']).sem()
tumor_sem = reg_sem.loc[:,'Tumor Volume (mm3)']

tumor_mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.382993
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Assemble the resulting series into a single summary dataframe.
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

reg_summary = pd.DataFrame(
    {"Tumor Volume (mm3) Mean": (tumor_mean),
    "Tumor Volume (mm3) Median": (tumor_median),
    "Tumor Volume (mm3) Variance": (tumor_var),
    "Tumor Volume (mm3) Standard Deviation": (tumor_std),
    "Tumor Volumr (mm3) SEM": (tumor_sem)
    })
reg_summary
# Out:
#               Tumor Volume (mm3) Mean  Tumor Volume (mm3) Median  \
# Drug Regimen
# Capomulin                   40.675741                  41.557809
# Ceftamin                    52.591172                  51.776157
# Infubinol                   52.884795                  51.820584
# Ketapril                    55.235638                  53.698743
# Naftisol                    54.331565                  52.509285
# Placebo                     54.033581                  52.288934
# Propriva                    52.382993                  50.783528
# Ramicane                    40.216745                  40.673236
# Stelasyn                    54.233149                  52.431737
# Zoniferol                   53.236507                  51.818479
#
#               Tumor Volume (mm3) Variance  \
# Drug Regimen
# Capomulin                       24.947764
# Ceftamin                        39.290177
# Infubinol                       43.128684
# Ketapril                        68.553577
# ...

# %%
# Using the aggregation method, produce the same summary statistics in a single line

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

mice_unique = pd.unique(mouse_study_clean["Mouse ID"])
#len(mice_unique)
reg_m_unique = mouse_study_clean.drop_duplicates(subset=['Mouse ID', 'Drug Regimen']).copy()
#len(reg_m_unique)
#reg_m_unique.head()
mice_grp = reg_m_unique.groupby(['Drug Regimen']).count()
#print(mice_grp)
just_mice = mice_grp.loc[:, 'Mouse ID']
#just_mice


ax = just_mice.plot.bar(x='Drug Regimen', y='Mouse ID')

# %%
mice2 = reg_m_unique.groupby(['Mouse ID', 'Drug Regimen']).count().reset_index()
mice3 = pd.unique(mice2['Drug Regimen'])

#df1 = pd.DataFrame( { "Mouse ID": [just_mice],
                    #"Drug Regimen": [mice3]})

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
height = len(just_mice)

drugs = mice2['Drug Regimen']


plt.bar(drugs,height,align='center')
plt.title('Mice Tested Per Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mf1 = reg_m_unique.loc[:, 'Sex']
mf2 = mf1.value_counts()
mf = pd.DataFrame(mf2)
mf_sum = mf['Sex'].sum()
male = 125
female = 124

male_pct = (male / mf_sum) * 100
female_pct = (female / mf_sum) *100
index = (0,1)
mf['Index'] = index


pct = [male_pct, female_pct]

mf['Percentage'] = pct
mf.reset_index()

mf_labels = 'Male', 'Female'
mf_explode = (0,0.1)
mf_colors = ["lightsteelblue", "silver"]
fig1, ax1 = plt.subplots()
ax1.pie(pct,explode=mf_explode,autopct='%1.1f%%',labels=mf_labels,colors=mf_colors)
ax1.axis('equal')
plt.show()

# Dark Theme will make the pie chart appear to be missing info, must use light theme

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

mf1 = reg_m_unique.loc[:, 'Sex']
mf2 = mf1.value_counts()
mf = pd.DataFrame(mf2)
mf_sum = mf['Sex'].sum()
male = 125
female = 124

male_pct = (male / mf_sum) * 100
female_pct = (female / mf_sum) *100
index = (0,1)
mf['Index'] = index


pct = [male_pct, female_pct]

mf['Percentage'] = pct
mf.reset_index()


plt.pie(pct, labels=mf_labels,autopct= '%1.1f%%',colors=mf_colors,explode=mf_explode)
plt.title('Male vs Female Percentages')
plt.axis("equal")
plt.show()

# Dark Theme will make the pie chart appear to be missing info, must use light theme

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin[1], Ramicane[0], Infubinol[2], and Ceftamin[4]

# Start by getting the last (greatest) timepoint for each mouse

K403 = mouse_study_clean.loc[mouse_study_clean["Mouse ID"] == 'k403']
#time = K403.loc[:,'Timepoint']
#K403_stats = mouse1.describe()
#K403_tumor_max = K403['Tumor Volume (mm3)'].max()
#K403_time_max = K403['Timepoint'].max()
#print(mouse_study_clean['Timepoint'].value_counts())
K403_allstats = K403.describe()
#K403_allstats
mouse1_min = K403_allstats.loc['min', 'Timepoint']
#mouse1_min
mouse1_max = K403_allstats.loc['max', 'Timepoint']
#mouse1_max

m1_tumorVolmin = K403_allstats.loc[K403_allstats['Timepoint']==mouse1_min, 'Tumor Volume (mm3)']
#m1_tumorVolmin

m1_tumorVolmax = K403_allstats.loc[K403_allstats['Timepoint']==mouse1_max, 'Tumor Volume (mm3)']
#m1_tumorVolmax

size = float(m1_tumorVolmax) - float(m1_tumorVolmin)
#size

#drug_studies = mouse_study_clean['Drug Regimen'].unique()

capo_mice = mouse_study_clean.loc[mouse_study_clean["Drug Regimen"] == 'Capomulin']



ram_mice = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Ramicane']
infu_mice = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Infubinol']
ceft_mice = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Ceftamin']


capo_mice.head()

#print(mice_unique)

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
